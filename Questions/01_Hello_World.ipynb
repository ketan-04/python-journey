# %% [markdown]
# # 🧠 Topic 1: Hello World
# This notebook contains basic Python print statement practice questions and solutions.

# %% [markdown]
# ### 1️⃣ Question 1: Print 'Hello, World!'

# %%
print("Hello, World!")

# %% [markdown]
# ### 2️⃣ Question 2: Print your name and a short introduction

# %%
print("My name is Leeladhar, I am learning Python.")

# %% [markdown]
# ### 3️⃣ Question 3: Print multiple statements in one line using `;`

# %%
print("Hello"); print("Welcome to Python programming!")

# %% [markdown]
# ### 4️⃣ Question 4: Try printing with different quote styles

# %%
print('This is a single-quoted string')
print("This is a double-quoted string")
print('''This is a triple-quoted string''')

# %% [markdown]
# ### 5️⃣ Question 5: Print special characters like `\n` and `\t`

# %%
print("Hello\nWorld")
print("Hello\tWorld")

# %% [markdown]
# ### 6️⃣ Question 6: Use `print()` with multiple arguments

# %%
name = "Leeladhar"
age = 21
print("Name:", name, "Age:", age)
