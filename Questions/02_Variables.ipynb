# %% [markdown]
# # 🧮 Topic 2: Variables
# This notebook covers Python variable concepts with solved examples.

# %% [markdown]
# ### 1️⃣ Question 1: Create variables for your name, age, and city — print them

# %%
name = "Leeladhar"
age = 21
city = "Delhi"
print("Name:", name)
print("Age:", age)
print("City:", city)

# %% [markdown]
# ### 2️⃣ Question 2: Swap values of two variables without using a third variable

# %%
a = 5
b = 10
a, b = b, a
print("After swapping: a =", a, ", b =", b)

# %% [markdown]
# ### 3️⃣ Question 3: Assign the same value to multiple variables in one line

# %%
x = y = z = 100
print(x, y, z)

# %% [markdown]
# ### 4️⃣ Question 4: Create variables with valid and invalid names — observe errors

# %%
# Valid names
number1 = 10
_name = "valid"

# Invalid names (will cause errors if uncommented)
# 1number = 10  # invalid
# my-variable = 20  # invalid

# %% [markdown]
# ### 5️⃣ Question 5: Take user input for name and age, then print them

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print("Hello", name + "!", "You are", age, "years old.")

# %% [markdown]
# ### 6️⃣ Question 6: Use `type()` to print data types of different variables

# %%
x = 10
y = 5.5
z = "Python"
a = True
print(type(x))
print(type(y))
print(type(z))
print(type(a))

# %% [markdown]
# ### 7️⃣ Question 7: Update a variable value and print both old and new values

# %%
price = 100
print("Old Price:", price)
price = 120
print("Updated Price:", price)
