# %% [markdown]
# # 🔢 Topic 3: Data Types
# This notebook explores different Python data types with examples.

# %% [markdown]
# ### 1️⃣ Question 1: Create examples for all basic data types

# %%
integer_num = 10
float_num = 3.14
string_text = "Hello"
boolean_val = True
list_data = [1, 2, 3, 4, 5]
tuple_data = (10, 20, 30)
set_data = {1, 2, 2, 3, 4}
dict_data = {"name": "Leeladhar", "age": 21, "city": "Delhi"}
print(integer_num, float_num, string_text, boolean_val, list_data, tuple_data, set_data, dict_data)

# %% [markdown]
# ### 2️⃣ Question 2: Check the type of a variable using `type()`

# %%
x = 42
print(type(x))

# %% [markdown]
# ### 3️⃣ Question 3: Convert one data type to another

# %%
x = 10
y = str(x)
z = float(x)
print("String:", y, type(y))
print("Float:", z, type(z))

# %% [markdown]
# ### 4️⃣ Question 4: Create a dictionary and print its values

# %%
person = {"name": "Leeladhar", "age": 21, "city": "Delhi"}
print("Name:", person["name"])
print("Age:", person["age"])
print("City:", person["city"])

# %% [markdown]
# ### 5️⃣ Question 5: Make a list of 5 numbers and find max, min, and sum

# %%
numbers = [10, 20, 30, 40, 50]
print("Max:", max(numbers))
print("Min:", min(numbers))
print("Sum:", sum(numbers))

# %% [markdown]
# ### 6️⃣ Question 6: Create a tuple and try modifying it

# %%
my_tuple = (1, 2, 3)
# my_tuple[0] = 10  # Uncommenting this will cause an error
print("Tuples are immutable:", my_tuple)

# %% [markdown]
# ### 7️⃣ Question 7: Create a set with duplicate elements

# %%
my_set = {1, 2, 2, 3, 4, 4}
print("Set (duplicates removed):", my_set)
