# %%
# Ask the user to enter a number. Convert it to an integer and add 10. Then print the result.

# Input:

# Enter a number: 15

# Output:

# Result: 25


num  = (input("enter number to convert:"))
print(int(num)+10)
# Out:
# 22

# %%
# Ask the user to enter a decimal number. Convert it to a float and display the value.

# Input:

# Enter a decimal number: 3.14

# Output:

# Float value is: 3.14

num1= input("enter decimal values:")
print(float(num1))
# Out:
# 3.14

# %%
# Ask the user to enter two numbers. Convert both to integers, multiply them, and print the product.

# Input:

# Enter first number: 6

# Enter second number: 4

# Output:

# Product: 24

num2= input("enter first number :")
num3= input("enter second number:")
print(int(num2) * int(num3))
# Out:
# 24

# %%
# Ask the user to enter their name and age. Convert the age to an integer and display a message using both values.

# Input:

# Enter your name: Anjali

# Enter your age: 22

# Output:

# Hello Anjali, you are 22 years old.

name = input("enter name :")
age = input("enter age :")
print("Hello" , name , "you are" , int(age) , "years old")
# Out:
# Hello ketan you are 20 years old

# %%
# Ask the user to enter a number. Convert that number to a string and print it along with another message.

# Input:

# Enter any number: 100

# Output:

# You entered number: 100

string = int(input("enter number"))
print("you entered number :" , str(string))
# Out:
# you entered number : 34

# %%
# Ask the user to enter a list of numbers separated by commas (for example: 1,2,3). Split the input by commas, convert each item to an integer, and store them in a list. Then print the list.

# Input:

# Enter numbers: 1,2,3,4

# Output:

# [1, 2, 3, 4]

l = input("enter list of numbers :")
