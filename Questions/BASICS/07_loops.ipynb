# %% [markdown]
# #### **1. Print numbers from 1 to 5 using `range()`**
#
# #### Use a `for` loop and `range()` to print numbers from 1 to 5.
#
# #### **Input:**
#
# #### List of numbers: `range(1, 6)`

# %%
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### **2. Print even numbers from 1 to 10**
#
# #### Loop through numbers from 1 to 10. Print only even numbers using a condition.
#
# #### **Input:**
#
# #### Numbers: `1 to 10`

# %%
for i in range(1,11):
    if i % 2 == 0 :
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# ### **4. Print each character of a string on a new line**
#
# #### Use a loop to print each letter of the string.
#
# #### **Input:**
#
# #### String: `"hello"`

# %%
st= "hello"
for i in st:
    print(i)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# ### **6. Count how many times a character appears in a string using loop**
#
# #### Use a loop and condition to count a specific character.
#
# #### **Input:**
#
# #### String: `"banana"`
#
# #### Character to count: `'a'`

# %%
st1="banana"
co=0
for i in st1:
    if i == 'a':
        co+=1
print("thw word'a' appears ",co,"times")
# Out:
# thw word'a' appears  3 times

# %% [markdown]
# ### **9. Print multiplication table of 3 using a loop**
#
# #### Use a `for` loop to print multiplication table from 1 to 10.
#
# #### **Input:**
#
# #### Number: `3`

# %%
num=3
for i in range(1,11):
    print(num ,"*", i,"=", num*i)
# Out:
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30

# %% [markdown]
# # WHILE LOOP

# %% [markdown]
# ### **1. Print numbers from 1 to 5 using a while loop**
#
# Use a `while` loop to print numbers starting from 1 up to 5.

# %%
num=1
while num<=5:
    print(num)
    num+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### **2. Print the reverse of a number using a while loop**
#
# Use a loop to reverse the digits of the number.

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 n=0
#       3 new=""
# ----> 4 while n<len(numb):
#       5     a=numb[::-1]
#       6     new=a
#
# KeyboardInterrupt:
