# %% [markdown]
# ###  Join a list of words into a sentence**
#
# Use `' '.join(list)` to join a list into a sentence.

# %%
name = ["my","name","is","ketan."]

print(" ".join(name))
# Out:
# my name is ketan.

# %% [markdown]
# ###  Convert a sentence to a list of words**
#
# Ask the user to enter a sentence. Use `.split()` to convert it into a list of words.

# %%
s=input("enter the sentence:")
t= s.split()
print(t)
# Out:
# ['i', 'am', 'going', 'to', 'do', 'it.']

# %% [markdown]
# ###  Add an item to a list**
#
# Start with a list. Ask the user to enter a new item, and use `.append()` to add it.

# %%
items = ["apple", "banana", "cherry"]

print("Current list:", items)

new_item = input("Enter a new item to add: ")


items.append(new_item)


print("Updated list:", items)
# Out:
# Current list: ['apple', 'banana', 'cherry']
# Updated list: ['apple', 'banana', 'cherry', 'guava']

# %% [markdown]
# ### Check if an item exists in a list**
#
# Ask the user for a fruit name. Use `in` to check if it exists in the li

# %%
items = ["apple", "banana", "cherry"]
new_f= input("enter fruits to check:")
print(new_f in items)
# Out:
# False

# %% [markdown]
# ### **8. Print the first and last elements of a list**
#
# Ask the user to enter items separated by commas. Convert to list and print the first and last item.

# %%
n=[]
d=0
while d>10:
    elem= input("enter new element:")
    no= ",".join(elem)
    d+=1
print(n)
# Out:
# []

# %% [markdown]
# above question is not completed at all
