# %% [markdown]
# Create a tuple of your 5 favorite colors and print the second and last color.

# %%
fav_color=("red","blue","white","green","violet","red","blue")
print(fav_color[1],fav_color[-2])
# Out:
# blue green

# %% [markdown]
# Find how many times a specific number appears in a tuple.

# %%
d=(87,4,5,6,3,4,6,5,55,44,6,5)
print(d.count(5))
# Out:
# 3

# %% [markdown]
# Convert a tuple to a list, add an element, and convert it back.

# %%
d=(87,4,5,6,3,4,6,5,55,44,6,5)
f= list(d)
print(list(d))
c=tuple(f)
print(c)
# Out:
# [87, 4, 5, 6, 3, 4, 6, 5, 55, 44, 6, 5]
# (87, 4, 5, 6, 3, 4, 6, 5, 55, 44, 6, 5)

# %% [markdown]
# Create a nested tuple and access inner elements.

# %%
nested_tuple = (1, 2, (3, 4, 5), (6, (7, 8)))
print(nested_tuple[0])
# Out:
# 1
